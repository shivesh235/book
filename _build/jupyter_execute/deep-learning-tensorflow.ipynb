# %% [markdown]
# # Tensorflow

# %%
import numpy as np
X = np.random.randn(100, 1)
y = X + 9

X_test = np.random.randn(10, 1)
y_test = X_test + 9

# %%
model = keras.Sequential([
    keras.layers.Dense(10, input_shape=[1]),
    keras.layers.Dense(1)
])

model.compile(loss = 'mae',
              optimizer = 'SGD',
              metrics = 'mae' )

model.fit(X, y, epochs=5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 model = keras.Sequential([
#       2     keras.layers.Dense(10, input_shape=[1]),
#       3     keras.layers.Dense(1)
#       4 ])
#       6 model.compile(loss = 'mae',
#       7               optimizer = 'SGD',
#       8               metrics = 'mae' )
#      10 model.fit(X, y, epochs=5)
#
# NameError: name 'keras' is not defined

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_2 (Dense)             (None, 10)                20
#
#  dense_3 (Dense)             (None, 1)                 11
#
# ...
# Total params: 31 (124.00 Byte)
# Trainable params: 31 (124.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
y_pred = model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 72ms/step

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 7))
plt.scatter(x=X, y=y, c='b', label='Training Data')
plt.scatter(x=X_test, y=y_test, c='g', label='Test Data')
plt.scatter(x=X_test, y=y_pred, c='r', label='Predictions')
plt.legend();
